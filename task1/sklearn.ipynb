# %%
import numpy as np
import pandas as pd
import sklearn

# %%
train_tsv = pd.read_csv('./data/train.tsv', sep='\t')
x_train = train_tsv['Phrase']
y_train = train_tsv['Sentiment']

# %%
from sklearn.feature_extraction.text import CountVectorizer
counter = CountVectorizer()
train_counts = counter.fit_transform(x_train)

# %%
counter.vocabulary_
# Out:
# {'series': 11837,
#  'of': 9227,
#  'escapades': 4577,
#  'demonstrating': 3490,
#  'the': 13505,
#  'adage': 288,
#  'that': 13503,
#  'what': 14871,
#  'is': 7217,
#  'good': 5821,
#  'for': 5323,
#  'goose': 5837,
#  'also': 529,
#  'gander': 5595,
#  'some': 12424,
#  'which': 14888,
#  'occasionally': 9204,
#  'amuses': 602,
#  'but': 1879,
#  'none': 9085,
#  'amounts': 593,
#  'to': 13681,
#  'much': 8807,
#  'story': 12857,
#  'this': 13556,
#  'quiet': 10585,
#  'introspective': 7143,
#  'and': 625,
#  'entertaining': 4500,
#  'independent': 6840,
#  'worth': 15096,
#  'seeking': 11750,
#  'even': 4642,
#  'fans': 4942,
#  'ismail': 7222,
#  'merchant': 8449,
#  'work': 15068,
#  'suspect': 13190,
#  'would': 15100,
#  'have': 6210,
#  'hard': 6156,
#  'time': 13644,
#  'sitting': 12159,
#  'through': 13598,
#  'one': 9272,
#  'positively': 10123,
#  'thrilling': 13591,
#  'combination': 2573,
#  'ethnography': 4621,
#  'all': 506,
#  'intrigue': 7133,
#  'betrayal': 1348,
#  'deceit': 3353,
#  'murder': 8831,
#  'shakespearean': 11909,
#  'tragedy': 13799,
#  'or': 9326,
#  'juicy': 7400,
#  'soap': 12372,
#  'opera': 9296,
#  'aggressive': 432,
#  'self': 11774,
#  'glorification': 5775,
#  'manipulative': 8215,
#  'whitewash': 14913,
#  'comedy': 2586,
#  'drama': 4026,
#  'nearly': 8961,
#  'epic': 4534,
#  'proportions': 10405,
#  'rooted': 11346,
#  'in': 6785,
#  'sincere': 12130,
#  'performance': 9759,
#  'by': 1894,
#  'title': 13674,
#  'character': 2178,
#  'undergoing': 14142,
#  'midlife': 8510,
#  'crisis': 3111,
#  'narratively': 8922,
#  'trouble': 13933,
#  'every': 4656,
#  'day': 3309,
#  'plodding': 9997,
#  'mess': 8468,
#  'importance': 6751,
#  'being': 1284,
#  'earnest': 4198,
#  'so': 12370,
#  'thick': 13540,
#  'with': 15008,
#  'wit': 15006,
#  'it': 7229,
#  'plays': 9973,
#  'like': 7865,
#  'reading': 10735,
#  'from': 5488,
#  'bartlett': 1178,
#  'familiar': 4925,
#  'quotations': 10603,
#  'does': 3921,
#  'leave': 7751,
#  'you': 15185,
#  'could': 2979,
#  'hate': 6196,
#  'same': 11494,
#  'reason': 10759,
#  'there': 13530,
#  'little': 7931,
#  'recommend': 10799,
#  'snow': 12365,
#  'dogs': 3929,
#  'unless': 14293,
#  'considers': 2806,
#  'cliched': 2428,
#  'dialogue': 3648,
#  'perverse': 9807,
#  'escapism': 4581,
#  'source': 12486,
#  'high': 6345,
#  'hilarity': 6361,
#  'kung': 7583,
#  'pow': 10158,
#  'oedekerk': 9225,
#  'realization': 10748,
#  'his': 6381,
#  'childhood': 2270,
#  'dream': 4052,
#  'be': 1209,
#  'martial': 8275,
#  'arts': 849,
#  'flick': 5234,
#  'proves': 10428,
#  'sometimes': 12434,
#  'dreams': 4057,
#  'youth': 15193,
#  'should': 12024,
#  'remain': 10969,
#  'just': 7420,
#  'performances': 9760,
#  'are': 784,
#  'an': 605,
#  'absolute': 175,
#  'joy': 7380,
#  'fresnadillo': 5457,
#  'has': 6191,
#  'something': 12431,
#  'serious': 11839,
#  'say': 11560,
#  'about': 166,
#  'ways': 14787,
#  'extravagant': 4837,
#  'chance': 2164,
#  'can': 1963,
#  'distort': 3863,
#  'our': 9375,
#  'perspective': 9800,
#  'throw': 13600,
#  'us': 14436,
#  'off': 9228,
#  'path': 9652,
#  'sense': 11793,
#  'still': 12811,
#  'moonlight': 8708,
#  'mile': 8526,
#  'better': 1352,
#  'judgment': 7392,
#  'damned': 3254,
#  'welcome': 14842,
#  'relief': 10957,
#  'baseball': 1180,
#  'movies': 8799,
#  'try': 13959,
#  'too': 13718,
#  'mythic': 8882,
#  'sweet': 13224,
#  'modest': 8655,
#  'ultimately': 14053,
#  'winning': 14982,
#  'bilingual': 1383,
#  'charmer': 2203,
#  'woman': 15035,
#  'who': 14914,
#  'inspired': 7015,
#  'less': 7799,
#  'dizzily': 3897,
#  'gorgeous': 5843,
#  'companion': 2628,
#  'mr': 8802,
#  'wong': 15050,
#  'mood': 8703,
#  'love': 8028,
#  'very': 14554,
#  'hong': 6452,
#  'kong': 7565,
#  'movie': 8791,
#  'despite': 3585,
#  'its': 7241,
#  'mainland': 8152,
#  'setting': 11864,
#  'as': 856,
#  'inept': 6884,
#  'big': 1375,
#  'screen': 11674,
#  'remakes': 10974,
#  'avengers': 1015,
#  'wild': 14943,
#  'west': 14863,
#  'everything': 4661,
#  'expect': 4757,
#  'nothing': 9123,
#  'more': 8725,
#  'best': 1343,
#  'indie': 6849,
#  'year': 15162,
#  'far': 4951,
#  'hatfield': 6200,
#  'hicks': 6336,
#  'make': 8166,
#  'oddest': 9215,
#  'couples': 2995,
#  'becomes': 1242,
#  'study': 12957,
#  'gambles': 5587,
#  'publishing': 10471,
#  'world': 15083,
#  'offering': 9235,
#  'case': 2059,
#  'exists': 4748,
#  'apart': 710,
#  'political': 10057,
#  'ramifications': 10656,
#  'going': 5806,
#  'house': 6519,
#  'party': 9618,
#  'watching': 14768,
#  'host': 6504,
#  'defend': 3396,
#  'himself': 6366,
#  'against': 418,
#  'frothing': 5494,
#  'ex': 4678,
#  'girlfriend': 5738,
#  'chuck': 2328,
#  'norris': 9103,
#  'grenade': 5943,
#  'gag': 5566,
#  'occurs': 9210,
#  'times': 13651,
#  'during': 4156,
#  'windtalkers': 14973,
#  'indication': 6846,
#  'how': 6526,
#  'minded': 8548,
#  'film': 5111,
#  'plot': 10000,
#  'romantic': 11331,
#  'boilerplate': 1563,
#  'start': 12733,
#  'finish': 5140,
#  'arrives': 824,
#  'impeccable': 6727,
#  'pedigree': 9710,
#  'mongrel': 8680,
#  'pep': 9736,
#  'almost': 522,
#  'indecipherable': 6835,
#  'complications': 2672,
#  'clearly': 2414,
#  'means': 8377,
#  'preach': 10186,
#  'exclusively': 4717,
#  'converted': 2900,
#  'while': 14891,
#  'offers': 9237,
#  'opportunities': 9307,
#  'occasional': 9203,
#  'smiles': 12314,
#  'chuckles': 2330,
#  'give': 5742,
#  'theater': 13506,
#  'beyond': 1362,
#  'wilde': 14945,
#  'actors': 277,
#  'latest': 7680,
#  'vapid': 14485,
#  'actor': 273,
#  'exercise': 4728,
#  'appropriate': 755,
#  'structure': 12932,
#  'arthur': 835,
#  'schnitzler': 11619,
#  'reigen': 10918,
#  'vaudeville': 14501,
#  'show': 12032,
#  'than': 13496,
#  'well': 14846,
#  'constructed': 2827,
#  'narrative': 8921,
#  'on': 9270,
#  'those': 13565,
#  'terms': 13466,
#  'inoffensive': 6978,
#  'actually': 283,
#  'rather': 10699,
#  'run': 11414,
#  'mill': 8536,
#  'action': 264,
#  'hampered': 6107,
#  'no': 9066,
#  'paralyzed': 9573,
#  'indulgent': 6875,
#  'script': 11689,
#  'aims': 464,
#  'poetry': 10029,
#  'ends': 4432,
#  'up': 14395,
#  'sounding': 12480,
#  'satire': 11532,
#  'ice': 6618,
#  'age': 420,
#  'first': 5153,
#  'computer': 2692,
#  'generated': 5657,
#  'feature': 5014,
#  'cartoon': 2051,
#  'feel': 5023,
#  'other': 9365,
#  'makes': 8169,
#  'glacial': 5746,
#  'pacing': 9493,
#  'early': 4194,
#  'here': 6308,
#  'makers': 8168,
#  'serve': 11848,
#  'cliches': 2429,
#  'considerable': 2801,
#  'dash': 3291,
#  'cattaneo': 2096,
#  'followed': 5303,
#  'runaway': 11415,
#  'success': 13047,
#  'full': 5523,
#  'monty': 8700,
#  'different': 3679,
#  'they': 13538,
#  're': 10721,
#  'unnamed': 14306,
#  'easily': 4209,
#  'substitutable': 13028,
#  'forces': 5332,
#  'whatever': 14872,
#  'terror': 13476,
#  'heroes': 6317,
#  'horror': 6495,
#  'avoid': 1023,
#  'feels': 5026,
#  'if': 6650,
#  'interested': 7081,
#  'itself': 7242,
#  'amusing': 603,
#  'progression': 10368,
#  'into': 7122,
#  'rambling': 10653,
#  'incoherence': 6817,
#  'gives': 5744,
#  'new': 9018,
#  'meaning': 8374,
#  'phrase': 9856,
#  'fatal': 4977,
#  'error': 4572,
#  'do': 3900,
#  'judge': 7390,
#  'soon': 12447,
#  'dark': 3283,
#  'gritty': 5971,
#  'takes': 13306,
#  'totally': 13755,
#  'unexpected': 14214,
#  'directions': 3722,
#  'keeps': 7465,
#  'young': 15186,
#  'romantics': 11335,
#  'out': 9379,
#  'date': 3294,
#  'tartakovsky': 13347,
#  'team': 13379,
#  'freakish': 5429,
#  'powers': 10167,
#  'visual': 14632,
#  'charm': 2202,
#  'five': 5167,
#  'writers': 15127,
#  'slip': 12262,
#  'modern': 8651,
#  'rut': 11433,
#  'banality': 1126,
#  'vincent': 14603,
#  'gallo': 5583,
#  'right': 11239,
#  'at': 928,
#  'home': 6437,
#  'french': 5446,
#  'shocker': 11992,
#  'playing': 9970,
#  'usual': 14447,
#  'bad': 1079,
#  'boy': 1666,
#  'weirdo': 14839,
#  'role': 11314,
#  'primary': 10288,
#  'goal': 5793,
#  'frighten': 5475,
#  'disturb': 3875,
#  'then': 13521,
#  'works': 15080,
#  'spectacularly': 12537,
#  'shiver': 11986,
#  'inducing': 6870,
#  'nerve': 8999,
#  'rattling': 10704,
#  'ride': 11227,
#  '100': 2,
#  'minute': 8568,
#  'only': 9278,
#  '25': 82,
#  'minutes': 8570,
#  'decent': 3355,
#  'material': 8321,
#  'fortunately': 5380,
#  'option': 9322,
#  'sensational': 11790,
#  'true': 13942,
#  'crime': 3102,
#  'hell': 6286,
#  'jaunt': 7289,
#  'purists': 10520,
#  'might': 8517,
#  'experimental': 4773,
#  'storytelling': 12862,
#  'lrb': 8048,
#  'though': 13567,
#  'horrifying': 6493,
#  'rrb': 11388,
#  'tricky': 13893,
#  'satisfying': 11541,
#  'any': 702,
#  'david': 3302,
#  'mamet': 8191,
#  'airless': 468,
#  'cinematic': 2346,
#  'shell': 11960,
#  'games': 5591,
#  'sure': 13146,
#  'filmmaker': 5116,
#  'disagree': 3735,
#  'honestly': 6449,
#  'see': 11744,
#  'point': 10034,
#  'jones': 7364,
#  'tackled': 13286,
#  'meaty': 8386,
#  'subject': 13005,
#  'drawn': 4045,
#  'engaging': 4451,
#  'characters': 2188,
#  'peppering': 9740,
#  'pages': 9511,
#  'memorable': 8431,
#  'zingers': 15223,
#  'bloody': 1501,
#  'sunday': 13111,
#  'grace': 5867,
#  'call': 1934,
#  'prevention': 10273,
#  'place': 9930,
#  'blame': 1436,
#  'making': 8173,
#  'war': 14728,
#  'ever': 4651,
#  'made': 8125,
#  'clunky': 2491,
#  'tv': 14009,
#  'approach': 751,
#  'detailing': 3601,
#  'chapter': 2177,
#  'life': 7842,
#  'celebrated': 2115,
#  'irish': 7188,
#  'playwright': 9975,
#  'poet': 10025,
#  'drinker': 4075,
#  'finally': 5124,
#  'coming': 2599,
#  'down': 3993,
#  'miramax': 8576,
#  'deep': 3386,
#  'shelves': 11962,
#  'after': 409,
#  'couple': 2993,
#  'aborted': 164,
#  'attempts': 952,
#  'waking': 14690,
#  'reno': 11005,
#  'strong': 12926,
#  'letting': 7812,
#  'sleeping': 12241,
#  'lie': 7839,
#  'thanks': 13501,
#  'largely': 7662,
#  'williams': 14953,
#  'interesting': 7082,
#  'developments': 3625,
#  'processed': 10330,
#  '60': 108,
#  'rest': 11106,
#  'overexposed': 9429,
#  'waste': 14758,
#  'comes': 2587,
#  'across': 260,
#  'relic': 10955,
#  'bygone': 1896,
#  'era': 4559,
#  'convolutions': 2915,
#  'silly': 12108,
#  'plausible': 9960,
#  'perhaps': 9767,
#  'cliche': 2427,
#  'refreshing': 10886,
#  'both': 1638,
#  'lead': 7725,
#  'oscar': 9362,
#  'size': 12168,
#  'your': 15189,
#  'lives': 7939,
#  'mark': 8252,
#  'pellington': 9721,
#  'pop': 10080,
#  'thriller': 13589,
#  'kooky': 7566,
#  'overeager': 9428,
#  'spooky': 12619,
#  'subtly': 13040,
#  'myth': 8881,
#  'claude': 2399,
#  'chabrol': 2146,
#  'camera': 1949,
#  'way': 14784,
#  'gently': 5682,
#  'swaying': 13216,
#  'back': 1063,
#  'forth': 5377,
#  'cradles': 3028,
#  'veiling': 14515,
#  'tension': 13455,
#  'beneath': 1313,
#  'otherwise': 9368,
#  'tender': 13446,
#  'movements': 8789,
#  'transforms': 13823,
#  'shakespeare': 11908,
#  'deepest': 3389,
#  'tragedies': 13798,
#  'smart': 12301,
#  'screenplay': 11678,
#  'james': 7270,
#  'eric': 4561,
#  'horton': 6499,
#  'director': 3725,
#  'peter': 9816,
#  'fallon': 4916,
#  'pat': 9646,
#  'teeth': 13414,
#  'hurt': 6585,
#  'arriving': 825,
#  'particularly': 9607,
#  'moment': 8672,
#  'history': 6387,
#  'flickering': 5235,
#  'reminders': 10986,
#  'ties': 13634,
#  'bind': 1392,
#  'generic': 5663,
#  'villains': 14600,
#  'lack': 7606,
#  'their': 13513,
#  'funny': 5540,
#  'accents': 198,
#  'scenes': 11595,
#  'poorly': 10078,
#  'delivered': 3458,
#  'deeply': 3390,
#  'thought': 13568,
#  'most': 8749,
#  'thinking': 13547,
#  'films': 5119,
#  'gratuitous': 5915,
#  'distractions': 3870,
#  'impressed': 6760,
#  'upon': 14410,
#  'fun': 5529,
#  'downright': 4000,
#  'transparent': 13834,
#  'endless': 4428,
#  'assault': 886,
#  'embarrassingly': 4350,
#  'ham': 6100,
#  'fisted': 5161,
#  'sex': 11882,
#  'jokes': 7352,
#  'reek': 10858,
#  'rewrite': 11198,
#  'designed': 3572,
#  'garner': 5613,
#  'cooler': 2921,
#  'pg': 9822,
#  '13': 17,
#  'rating': 10700,
#  'provocative': 10438,
#  'impossible': 6755,
#  'gets': 5700,
#  'under': 14125,
#  'skin': 12197,
#  'man': 8192,
#  'we': 14790,
#  'know': 7554,
#  'evil': 4666,
#  'monstrous': 8696,
#  'lunatic': 8078,
#  'drive': 4079,
#  'many': 8227,
#  'things': 13544,
#  'stoner': 12841,
#  'midnight': 8511,
#  'sci': 11634,
#  'fi': 5069,
#  'deconstruction': 3375,
#  'gay': 5631,
#  'fantasia': 4943,
#  'above': 167,
#  'sanguine': 11515,
#  'two': 14032,
#  'skittish': 12207,
#  'york': 15181,
#  'middle': 8508,
#  'agers': 427,
#  'stumble': 12966,
#  'relationship': 10937,
#  'struggle': 12936,
#  'furiously': 5543,
#  'fears': 5009,
#  'foibles': 5295,
#  'ambition': 562,
#  'subjects': 13008,
#  'not': 9114,
#  'willingness': 14958,
#  'scherfig': 11605,
#  'will': 14951,
#  'wondering': 15043,
#  'clever': 2423,
#  'credits': 3081,
#  'roll': 11316,
#  'absorbing': 179,
#  'documentary': 3912,
#  'reeks': 10861,
#  'rot': 11359,
#  'hack': 6067,
#  'vignettes': 14594,
#  'clips': 2446,
#  'looking': 7989,
#  'common': 2618,
#  'line': 7891,
#  'contrived': 2882,
#  'pastiche': 9642,
#  'caper': 1987,
#  'major': 8163,
#  'problem': 10321,
#  'bulk': 1827,
#  'centers': 2132,
#  'wrong': 15132,
#  'swimfan': 13234,
#  'attraction': 963,
#  'eventually': 4650,
#  'goes': 5804,
#  'overboard': 9419,
#  'loony': 7992,
#  'melodramatic': 8421,
#  'denouement': 3500,
#  'school': 11621,
#  'swimming': 13235,
#  'pool': 10075,
#  'substitutes': 13030,
#  'bathtub': 1199,
#  'heartfelt': 6254,
#  'involving': 7178,
#  'unsettling': 14358,
#  'experience': 4769,
#  'predecessors': 10203,
#  'proud': 10423,
#  'pretty': 10267,
#  'execution': 4724,
#  'lot': 8015,
#  'richer': 11216,
#  'ones': 9273,
#  'hollywood': 6427,
#  'screenwriters': 11682,
#  'usually': 14448,
#  'come': 2580,
#  'own': 9482,
#  'phillip': 9832,
#  'noyce': 9145,
#  'cinematographer': 2348,
#  'christopher': 2324,
#  'doyle': 4006,
#  'understand': 14164,
#  'delicate': 3442,
#  'forcefulness': 5331,
#  'greene': 5936,
#  'prose': 10412,
#  'version': 14549,
#  'american': 573,
#  'pianist': 9862,
#  'lacks': 7611,
#  'quick': 10581,
#  'emotional': 4372,
#  'connections': 2784,
#  'steven': 12794,
#  'spielberg': 12562,
#  'schindler': 11607,
#  'list': 7917,
#  'inventive': 7154,
#  'intoxicatingly': 7127,
#  'sexy': 11892,
#  'violent': 14608,
#  'maddening': 8123,
#  'tells': 13428,
#  'fascinating': 4966,
#  'compelling': 2644,
#  'written': 15131,
#  'flatly': 5202,
#  'kendall': 7468,
#  'directed': 3718,
#  'barely': 1153,
#  'mary': 8287,
#  'co': 2496,
#  'writer': 15126,
#  'ed': 4235,
#  'decter': 3380,
#  'highly': 6353,
#  'recommended': 10801,
#  'viewing': 14590,
#  'courage': 2997,
#  'ideas': 6636,
#  'technical': 13391,
#  'proficiency': 10353,
#  'great': 5927,
#  'acting': 263,
#  'imax': 6690,
#  'short': 12014,
#  'wonderful': 15041,
#  'shows': 12042,
#  'slice': 12248,
#  'yet': 15172,
#  'instantly': 7024,
#  'recognizable': 10793,
#  'amid': 579,
#  'shock': 11990,
#  'curiosity': 3197,
#  'factors': 4882,
#  'corny': 2953,
#  'examination': 4685,
#  'actress': 279,
#  'trying': 13960,
#  'find': 5127,
#  'her': 6306,
#  'lazy': 7722,
#  'solving': 12422,
#  'distract': 3866,
#  'solution': 12420,
#  'another': 673,
#  'comprehensible': 2682,
#  'dummies': 4144,
#  'guide': 6027,
#  'non': 9078,
#  'techies': 13390,
#  'enjoy': 4469,
#  'entertains': 4504,
#  'because': 1236,
#  'music': 8848,
#  'comic': 2594,
#  'antics': 689,
#  'pleasure': 9987,
#  'disney': 3814,
#  'scrape': 11664,
#  'bottom': 1643,
#  'cracker': 3022,
#  'barrel': 1166,
#  'burr': 1862,
#  'steers': 12771,
#  'emphasizes': 4382,
#  'quirky': 10596,
#  'mixed': 8629,
#  'results': 11121,
#  'scarcely': 11574,
#  'mention': 8443,
#  'reporting': 11031,
#  'number': 9154,
#  'tumbleweeds': 13974,
#  'blowing': 1504,
#  'empty': 4394,
#  'theatres': 13509,
#  'graced': 5868,
#  'company': 2631,
#  'invigorating': 7164,
#  'surreal': 13166,
#  'resonant': 11084,
#  'rainbow': 10636,
#  'emotion': 4371,
#  'analyze': 612,
#  'crass': 3048,
#  'sequels': 11823,
#  'fails': 4896,
#  'second': 11726,
#  'guess': 6021,
#  'affection': 386,
#  'original': 9351,
#  'report': 11027,
#  'card': 2008,
#  'live': 7933,
#  'exalted': 4683,
#  'tagline': 13298,
#  'definite': 3410,
#  'room': 11343,
#  'improvement': 6776,
#  'neither': 8991,
#  'monsterous': 8694,
#  'tsai': 13962,
#  'may': 8341,
#  'ploughing': 10006,
#  'furrow': 5544,
#  'once': 9271,
#  'often': 9243,
#  'green': 5935,
#  'equivalent': 4556,
#  'saddam': 11455,
#  'hussein': 6591,
#  'ready': 10737,
#  'go': 5792,
#  'ask': 867,
#  'permission': 9775,
#  'preemptive': 10211,
#  'strike': 12908,
#  'surprisingly': 13165,
#  'solid': 12411,
#  'achievement': 239,
#  'malcolm': 8179,
#  'lee': 7764,
#  'john': 7341,
#  'ridley': 11234,
#  'massoud': 8304,
#  'record': 10808,
#  'tenacious': 13441,
#  'humane': 6547,
#  'fighter': 5092,
#  'was': 14750,
#  'prisoner': 10307,
#  'victim': 14570,
#  'changing': 2169,
#  'lanes': 7646,
#  'tries': 13896,
#  'shyamalan': 12065,
#  'stop': 12846,
#  'please': 9981,
#  'mom': 8671,
#  'macabre': 8107,
#  'stylized': 12994,
#  'swedish': 13221,
#  'fillm': 5109,
#  'city': 2364,
#  'where': 14882,
#  'religious': 10962,
#  'civic': 2365,
#  'virtues': 14615,
#  'hold': 6415,
#  'society': 12386,
#  'tatters': 13359,
#  'recent': 10780,
#  'memory': 8434,
#  'thoughtful': 13569,
#  'art': 829,
#  'ethics': 4617,
#  'cost': 2965,
#  'moral': 8713,
#  'compromise': 2686,
#  'consistently': 2811,
#  'unimaginative': 14260,
#  'probably': 10316,
#  'saved': 11551,
#  'aid': 453,
#  'wisecracking': 14992,
#  'mystery': 8876,
#  'science': 11635,
#  '3000': 88,
#  'guys': 6061,
#  'tian': 13619,
#  'zhuangzhuang': 15220,
#  'triumphantly': 13915,
#  'returns': 11153,
#  'filmmaking': 5118,
#  'visually': 14635,
#  'masterful': 8306,
#  'power': 10160,
#  'mawkish': 8337,
#  'parody': 9594,
#  'weird': 14834,
#  'masterpiece': 8311,
#  'sketch': 12179,
#  'view': 14586,
#  'nor': 9096,
#  'believe': 1293,
#  'puts': 10542,
#  'them': 13514,
#  'battle': 1204,
#  'wills': 14960,
#  'care': 2014,
#  'appreciate': 746,
#  'sided': 12076,
#  'theme': 13517,
#  'lawrence': 7709,
#  'over': 9413,
#  'tirade': 13663,
#  'knock': 7546,
#  'yourself': 15191,
#  'postcard': 10136,
#  'glorified': 5776,
#  'martin': 8276,
#  'lovefest': 8032,
#  'whole': 14916,
#  'sneaky': 12350,
#  'dupe': 4152,
#  'viewer': 14588,
#  'taking': 13307,
#  'important': 6752,
#  'simply': 12122,
#  'ugly': 14047,
#  'look': 7986,
#  'product': 10341,
#  'whenever': 14881,
#  'threatens': 13582,
#  'get': 5699,
#  'bogged': 1554,
#  'dramaturgy': 4035,
#  'stirring': 12824,
#  'sequence': 11824,
#  'surge': 13158,
#  'swirling': 13243,
#  'rapids': 10682,
#  'leap': 7739,
#  'pinnacle': 9900,
#  'rouses': 11373,
#  'swinging': 13238,
#  'seem': 11752,
#  'hobby': 6408,
#  'attracts': 966,
#  'fit': 5163,
#  'when': 14879,
#  'entirely': 4515,
#  'unprepared': 14322,
#  'devos': 3637,
#  'delivers': 3460,
#  'perfect': 9753,
#  'captures': 2005,
#  'innocence': 6968,
#  'budding': 1810,
#  'demons': 3486,
#  'within': 15012,
#  'wallflower': 14703,
#  '300': 87,
#  'years': 15165,
#  'russian': 11428,
#  'culture': 3187,
#  'compressed': 2684,
#  'evanescent': 4635,
#  'seamless': 11707,
#  'sumptuous': 13107,
#  'stream': 12888,
#  'consciousness': 2796,
#  'filmmakers': 5117,
#  'want': 14723,
#  'else': 4335,
#  'cheap': 2219,
#  'succeed': 13044,
#  'polanski': 10049,
#  'element': 4309,
#  'alone': 524,
#  'abandoned': 146,
#  'consoled': 2814,
#  'he': 6224,
#  'revealed': 11157,
#  ...}

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
tfidf = TfidfVectorizer(analyzer='word', ngram_range=(2,3), max_features=50000)
train_features = tfidf.fit_transform(x_train)

# %%
tfidf.vocabulary_
# Out:
# {'series of': 35248,
#  'that what': 39413,
#  'what is': 47661,
#  'is good': 20716,
#  'good for': 16256,
#  'for the': 14807,
#  'the goose': 40574,
#  'is also': 20547,
#  'some of': 36510,
#  'of which': 29324,
#  'but none': 7228,
#  'none of': 27208,
#  'which amounts': 47853,
#  'amounts to': 1524,
#  'to much': 44455,
#  'much of': 26443,
#  'of story': 28905,
#  'is good for': 20717,
#  'good for the': 16257,
#  'for the goose': 14824,
#  'but none of': 7230,
#  'none of which': 27213,
#  'of which amounts': 29325,
#  'which amounts to': 47854,
#  'amounts to much': 1526,
#  'to much of': 44456,
#  'much of story': 26451,
#  'and entertaining': 2396,
#  'is worth': 21063,
#  'fans of': 13325,
#  'would have': 49353,
#  'have hard': 17263,
#  'hard time': 16956,
#  'sitting through': 35950,
#  'through this': 43531,
#  'this one': 43180,
#  'have hard time': 17264,
#  'sitting through this': 35952,
#  'through this one': 43532,
#  'combination of': 8924,
#  'and all': 2007,
#  'all the': 1178,
#  'the intrigue': 40786,
#  'betrayal deceit': 6253,
#  'deceit and': 10276,
#  'and murder': 2832,
#  'murder of': 26502,
#  'soap opera': 36381,
#  'betrayal deceit and': 6254,
#  'deceit and murder': 10277,
#  'self glorification': 35096,
#  'comedy drama': 8992,
#  'drama of': 11412,
#  'of nearly': 28602,
#  'rooted in': 34144,
#  'performance by': 31471,
#  'by the': 7501,
#  'the title': 42155,
#  'title character': 43729,
#  'midlife crisis': 25252,
#  'the title character': 42156,
#  'trouble every': 45440,
#  'every day': 12704,
#  'day is': 10151,
#  'trouble every day': 45441,
#  'every day is': 12705,
#  'the importance': 40730,
#  'importance of': 19005,
#  'of being': 27785,
#  'being earnest': 6080,
#  'earnest so': 11711,
#  'with wit': 48904,
#  'it plays': 21372,
#  'plays like': 31825,
#  'like reading': 23289,
#  'reading from': 33196,
#  'from bartlett': 15217,
#  'bartlett familiar': 5398,
#  'familiar quotations': 13259,
#  'the importance of': 40731,
#  'importance of being': 19006,
#  'of being earnest': 27789,
#  'it plays like': 21374,
#  'plays like reading': 31826,
#  'like reading from': 23290,
#  'reading from bartlett': 33197,
#  'from bartlett familiar': 15218,
#  'bartlett familiar quotations': 5399,
#  'but it': 7196,
#  'it does': 21178,
#  'does leave': 11198,
#  'leave you': 22911,
#  'you with': 49790,
#  'with much': 48687,
#  'but it does': 7198,
#  'does leave you': 11199,
#  'leave you with': 22915,
#  'you could': 49607,
#  'hate it': 17153,
#  'it for': 21220,
#  'the same': 41721,
#  'it for the': 21222,
#  'there little': 42757,
#  'little to': 23521,
#  'to recommend': 44571,
#  'snow dogs': 36216,
#  'cliched dialogue': 8724,
#  'dialogue and': 10662,
#  'source of': 36771,
#  'of high': 28212,
#  'high hilarity': 17780,
#  'kung pow': 22575,
#  'realization of': 33276,
#  'of his': 28219,
#  'his childhood': 17935,
#  'childhood dream': 8405,
#  'to be': 43812,
#  'be in': 5595,
#  'in martial': 19397,
#  'martial arts': 24734,
#  'arts flick': 4240,
#  'flick and': 14388,
#  'proves that': 32633,
#  'that sometimes': 39310,
#  'dreams of': 11481,
#  'of youth': 29384,
#  'just that': 22277,
#  'his childhood dream': 17936,
#  'to be in': 43845,
#  'in martial arts': 19398,
#  'martial arts flick': 24735,
#  'the performances': 41411,
#  'performances are': 31483,
#  'an absolute': 1560,
#  'the performances are': 41412,
#  'has something': 17118,
#  'to say': 44610,
#  'say about': 34522,
#  'about the': 367,
#  'the ways': 42363,
#  'ways in': 47312,
#  'in which': 19778,
#  'which extravagant': 47865,
#  'extravagant chance': 13067,
#  'chance can': 8083,
#  'can distort': 7710,
#  'distort our': 11027,
#  'our perspective': 30617,
#  'perspective and': 31566,
#  'and throw': 3376,
#  'throw us': 43544,
#  'us off': 46297,
#  'off the': 29423,
#  'the path': 41387,
#  'path of': 31279,
#  'of good': 28152,
#  'good sense': 16302,
#  'to say about': 44611,
#  'about the ways': 384,
#  'the ways in': 42364,
#  'ways in which': 47313,
#  'in which extravagant': 19781,
#  'which extravagant chance': 47866,
#  'extravagant chance can': 13068,
#  'chance can distort': 8084,
#  'can distort our': 7711,
#  'distort our perspective': 11028,
#  'our perspective and': 30618,
#  'perspective and throw': 31567,
#  'and throw us': 3377,
#  'throw us off': 43545,
#  'us off the': 46298,
#  'off the path': 29428,
#  'the path of': 41388,
#  'path of good': 31281,
#  'of good sense': 28156,
#  'moonlight mile': 25616,
#  'be damned': 5516,
#  'welcome relief': 47453,
#  'movies that': 26341,
#  'too hard': 45104,
#  'hard to': 16958,
#  'be mythic': 5626,
#  'one is': 29945,
#  'is sweet': 20967,
#  'sweet and': 38125,
#  'and modest': 2796,
#  'and ultimately': 3431,
#  'ultimately winning': 45819,
#  'too hard to': 45106,
#  'hard to be': 16959,
#  'this one is': 43182,
#  'just like': 22253,
#  'like the': 23317,
#  'woman who': 49036,
#  'just like the': 22254,
#  'in the': 19572,
#  'the mood': 41092,
#  'mood for': 25607,
#  'love very': 23937,
#  'very much': 46582,
#  'hong kong': 18382,
#  'kong movie': 22567,
#  'despite its': 10571,
#  'in the mood': 19640,
#  'the mood for': 41093,
#  'love very much': 23938,
#  'hong kong movie': 18384,
#  'as big': 4280,
#  'big screen': 6396,
#  'of the': 28954,
#  'and the': 3314,
#  'the wild': 42395,
#  'everything you': 12792,
#  'you expect': 49622,
#  'expect but': 12940,
#  'but nothing': 7236,
#  'nothing more': 27477,
#  'the year': 42474,
#  'so far': 36267,
#  'of the year': 29142,
#  'make the': 24388,
#  'the oddest': 41274,
#  'and in': 2633,
#  'in this': 19708,
#  'the movie': 41134,
#  'study of': 37608,
#  'the gambles': 40516,
#  'gambles of': 15657,
#  'the publishing': 41571,
#  'publishing world': 32697,
#  'case study': 7913,
#  'study that': 37611,
#  'exists apart': 12924,
#  'apart from': 3882,
#  'from all': 15200,
#  'movie political': 26207,
#  'political ramifications': 32013,
#  'study of the': 37610,
#  'the gambles of': 40517,
#  'gambles of the': 15658,
#  'of the publishing': 29088,
#  'the publishing world': 41572,
#  'from all the': 15201,
#  'all the movie': 1197,
#  'the movie political': 41156,
#  'movie political ramifications': 26208,
#  'it like': 21297,
#  'going to': 16185,
#  'house party': 18520,
#  'and watching': 3507,
#  'watching the': 47229,
#  'frothing ex': 15409,
#  'ex girlfriend': 12819,
#  'frothing ex girlfriend': 15410,
#  'that the': 39342,
#  'of how': 28272,
#  'serious minded': 35261,
#  'minded the': 25354,
#  'the film': 40342,
#  'film is': 13902,
#  'serious minded the': 35262,
#  'minded the film': 25355,
#  'the film is': 40368,
#  'the plot': 41470,
#  'plot is': 31891,
#  'romantic comedy': 34112,
#  'from start': 15334,
#  'start to': 37149,
#  'to finish': 44188,
#  'the plot is': 41476,
#  'from start to': 15335,
#  'start to finish': 37150,
#  'with an': 48493,
#  'an impeccable': 1816,
#  'impeccable pedigree': 18992,
#  'pedigree mongrel': 31351,
#  'mongrel pep': 25577,
#  'and almost': 2012,
#  'impeccable pedigree mongrel': 18993,
#  'pedigree mongrel pep': 31352,
#  'film that': 13987,
#  'means to': 24980,
#  'to the': 44772,
#  'the converted': 39944,
#  'to the converted': 44791,
#  'while the': 47956,
#  'smiles and': 36180,
#  'does give': 11183,
#  'give us': 16009,
#  'us reason': 46305,
#  'reason to': 33342,
#  'the theater': 42092,
#  'theater beyond': 42492,
#  'beyond wilde': 6354,
#  'wilde wit': 48275,
#  'wit and': 48463,
#  'the actors': 39497,
#  'actors performances': 700,
#  'it does give': 21181,
#  'does give us': 11184,
#  'us reason to': 46306,
#  'be in the': 5597,
#  'in the theater': 19678,
#  'the theater beyond': 42094,
#  'theater beyond wilde': 42493,
#  'beyond wilde wit': 6355,
#  'wilde wit and': 48276,
#  'wit and the': 48465,
#  'and the actors': 3315,
#  'the actors performances': 39501,
#  'the latest': 40857,
#  'the structure': 42006,
#  'structure of': 37558,
#  'the structure of': 42007,
#  'than well': 38793,
#  'well constructed': 47478,
#  'on those': 29840,
#  'inoffensive and': 20032,
#  'more than': 25836,
#  'run of': 34270,
#  'the mill': 41058,
#  'action flick': 618,
#  'nothing more than': 27478,
#  'run of the': 34271,
#  'of the mill': 29058,
#  'self indulgent': 35110,
#  'script that': 34758,
#  'that aims': 38824,
#  'for poetry': 14724,
#  'poetry and': 31936,
#  'and ends': 2381,
#  'ends up': 12159,
#  'sounding like': 36756,
#  'and ends up': 2382,
#  'ice age': 18756,
#  'age is': 967,
#  'is the': 20980,
#  'the first': 40430,
#  'computer generated': 9220,
#  'generated feature': 15755,
#  'feature cartoon': 13517,
#  'to feel': 44155,
#  'feel like': 13551,
#  'like other': 23276,
#  'other movies': 30526,
#  'movies and': 26307,
#  'and that': 3311,
#  'that makes': 39155,
#  'makes for': 24431,
#  'for some': 14774,
#  'early on': 11699,
#  'is the first': 20984,
#  'computer generated feature': 9222,
#  'generated feature cartoon': 15756,
#  'to feel like': 44158,
#  'like other movies': 23277,
#  'there very': 42776,
#  'very little': 46576,
#  'sense to': 35180,
#  'to what': 44939,
#  'what going': 47647,
#  'going on': 16178,
#  'on here': 29683,
#  'here but': 17721,
#  'but the': 7268,
#  'the makers': 40969,
#  'up the': 46198,
#  'the cliches': 39870,
#  'with considerable': 48542,
#  'what going on': 47648,
#  'going on here': 16179,
#  'should have': 35616,
#  'success of': 37766,
#  'his first': 17978,
#  'first film': 14237,
#  'film the': 13998,
#  'the full': 40494,
#  'full monty': 15447,
#  'with something': 48782,
#  'something different': 36578,
#  'of his first': 28226,
#  'his first film': 17979,
#  'first film the': 14240,
#  'film the full': 13999,
#  'the full monty': 40495,
#  'they re': 42853,
#  'that serve': 39289,
#  'the heroes': 40649,
#  'heroes of': 17741,
#  'of horror': 28265,
#  'horror movies': 18444,
#  'movies try': 26350,
#  'try to': 45518,
#  'to avoid': 43801,
#  'the heroes of': 40650,
#  'heroes of horror': 17742,
#  'of horror movies': 28266,
#  'horror movies try': 18446,
#  'movies try to': 26351,
#  'try to avoid': 45519,
#  'it almost': 21098,
#  'feels as': 13598,
#  'as if': 4410,
#  'if the': 18863,
#  'movie is': 26170,
#  'is more': 20797,
#  'more interested': 25748,
#  'interested in': 20238,
#  'in entertaining': 19225,
#  'entertaining itself': 12350,
#  'than in': 38691,
#  'in amusing': 19091,
#  'amusing us': 1550,
#  'feels as if': 13599,
#  'as if the': 4414,
#  'if the movie': 18868,
#  'the movie is': 41151,
#  'movie is more': 26172,
#  'more interested in': 25749,
#  'interested in entertaining': 20241,
#  'in entertaining itself': 19226,
#  'than in amusing': 38692,
#  'in amusing us': 19092,
#  'meaning to': 24963,
#  'the phrase': 41430,
#  'script error': 34750,
#  'meaning to the': 24964,
#  'one too': 30011,
#  'it dark': 21168,
#  'dark gritty': 10084,
#  'gritty story': 16595,
#  'story but': 37365,
#  'it takes': 21433,
#  'takes off': 38281,
#  'off in': 29406,
#  'totally unexpected': 45227,
#  'directions and': 10821,
#  'this one too': 43183,
#  'out on': 30716,
#  'has some': 17116,
#  'of visual': 29288,
#  'visual charm': 46790,
#  'the five': 40444,
#  'five writers': 14308,
#  'slip into': 36063,
#  'into the': 20389,
#  'the modern': 41081,
#  'of narrative': 28588,
#  'right at': 33932,
#  'at home': 4829,
#  'his usual': 18167,
#  'bad boy': 5236,
#  'right at home': 33933,
#  'horror movie': 18442,
#  'primary goal': 32417,
#  'is to': 20999,
#  'shiver inducing': 35519,
#  '100 minute': 16,
#  'minute movie': 25391,
#  'minutes of': 25410,
#  'of decent': 27960,
#  'still have': 37268,
#  'have that': 17331,
#  'less the': 23018,
#  'the sensational': 41796,
#  'like and': 23204,
#  'and more': 2810,
#  'more experimental': 25713,
#  'in its': 19339,
#  'its storytelling': 21878,
#  'no less': 27113,
#  'for it': 14635,
#  'it rrb': 21397,
#  'in its storytelling': 19350,
#  'and satisfying': 3107,
#  'as any': 4261,
#  'any of': 3795,
#  'of david': 27948,
#  'as any of': 4267,
#  'sure the': 37999,
#  'the filmmaker': 40403,
#  'filmmaker would': 14055,
#  'would disagree': 49346,
#  'do see': 11108,
#  'see the': 34899,
#  'the point': 41480,
#  'the filmmaker would': 40405,
#  'filmmaker would disagree': 14056,
#  'do see the': 11110,
#  'see the point': 34907,
#  'subject and': 37695,
#  'the pages': 41358,
#  'memorable zingers': 25078,
#  'has the': 17128,
#  'to call': 43925,
#  'call for': 7605,
#  'for prevention': 14732,
#  'prevention rather': 32382,
#  'rather than': 33069,
#  'than to': 38782,
#  'to place': 44510,
#  'place blame': 31743,
#  'making it': 24490,
#  'it one': 21361,
#  'one of': 29972,
#  'the best': 39669,
#  'best war': 6247,
#  'war movies': 47007,
#  'movies ever': 26314,
#  'ever made': 12668,
#  'call for prevention': 7606,
#  'for prevention rather': 14733,
#  'prevention rather than': 32383,
#  'rather than to': 33077,
#  'than to place': 38784,
#  'to place blame': 44511,
#  'making it one': 24492,
#  'it one of': 21363,
#  'one of the': 29979,
#  'of the best': 28968,
#  'the best war': 39681,
#  'best war movies': 6248,
#  'war movies ever': 47008,
#  'movies ever made': 26315,
#  'tv movie': 45630,
#  'approach to': 3942,
#  'the life': 40888,
#  'life of': 23129,
#  'the celebrated': 39786,
#  'celebrated irish': 7993,
#  'irish playwright': 20499,
#  'playwright poet': 31832,
#  'poet and': 31929,
#  'and drinker': 2352,
#  'the life of': 40889,
#  'life of the': 23131,
#  'the celebrated irish': 39787,
#  'celebrated irish playwright': 7994,
#  'irish playwright poet': 20500,
#  'playwright poet and': 31833,
#  'poet and drinker': 31930,
#  'coming down': 9087,
#  'down off': 11349,
#  'off of': 29413,
#  'of miramax': 28538,
#  'miramax deep': 25430,
#  'deep shelves': 10328,
#  'couple of': 9632,
#  'of aborted': 27667,
#  'aborted attempts': 213,
#  'waking up': 46910,
#  'up in': 46154,
#  'in reno': 19504,
#  'makes strong': 24454,
#  'case for': 7908,
#  'coming down off': 9088,
#  'of miramax deep': 28540,
#  'miramax deep shelves': 25431,
#  'couple of aborted': 9633,
#  'of aborted attempts': 27668,
#  'waking up in': 46911,
#  'up in reno': 46162,
#  'interesting developments': 20257,
#  'in 60': 19071,
#  '60 minutes': 146,
#  'the rest': 41647,
#  'is just': 20754,
#  'just an': 22211,
#  'waste of': 47157,
#  'of film': 28082,
#  'in 60 minutes': 19072,
#  'comes across': 9026,
#  'across as': 534,
#  'from bygone': 15229,
#  'bygone era': 7553,
#  'era and': 12441,
#  'and its': 2668,
#  'its convolutions': 21606,
#  'comes across as': 9027,
#  'from bygone era': 15230,
#  'bygone era and': 7554,
#  'era and its': 12442,
#  'and its convolutions': 2671,
#  'perhaps it': 31502,
#  'cliche to': 8721,
#  'call the': 7610,
#  'film refreshing': 13959,
#  'it is': 21270,
#  'cliche to call': 8722,
#  'to call the': 43927,
#  'call the film': 7611,
#  'the film refreshing': 40383,
#  'but it is': 7201,
#  'lead performances': 22830,
#  'run for': 34266,
#  'for your': 14908,
#  'your lives': 49910,
#  'thriller is': 43466,
#  'is as': 20567,
#  'as it': 4424,
#  'is spooky': 20946,
#  'spooky and': 36974,
#  'and subtly': 3266,
#  'in love': 19381,
#  'love with': 23939,
#  'with myth': 48692,
#  'as it is': 4429,
#  'is spooky and': 20947,
#  'spooky and subtly': 36975,
#  'in love with': 19382,
#  'love with myth': 23943,
#  'claude chabrol': 8657,
#  'way of': 47282,
#  'back and': 5184,
#  'and forth': 2475,
#  'it cradles': 21166,
#  'cradles its': 9681,
#  'its characters': 21584,
#  'characters veiling': 8254,
#  'veiling tension': 46493,
#  'tension beneath': 38552,
#  'beneath otherwise': 6173,
#  'otherwise tender': 30574,
#  'tender movements': 38542,
#  'back and forth': 5186,
#  'it cradles its': 21167,
#  'cradles its characters': 9682,
#  'its characters veiling': 21588,
#  'characters veiling tension': 8255,
#  'veiling tension beneath': 46494,
#  'tension beneath otherwise': 38553,
#  'beneath otherwise tender': 6174,
#  'otherwise tender movements': 30575,
#  'of lrb': 28468,
#  'one of lrb': 29976,
#  'the screenplay': 41759,
#  'by james': 7399,
#  'and director': 2321,
#  'director peter': 10883,
#  'peter fallon': 31585,
#  'is so': 20928,
#  'it makes': 21310,
#  'makes your': 24476,
#  'your teeth': 49952,
#  'teeth hurt': 38486,
#  'and director peter': 2324,
#  'it makes your': 21312,
#  'your teeth hurt': 49953,
#  'moment in': 25534,
#  'in history': 19320,
#  'history it': 18214,
#  'it offers': 21359,
#  'flickering reminders': 14404,
#  'the ties': 42133,
#  'bind us': 6429,
#  'of the ties': 29121,
#  'lrb other': 24092,
#  'other than': 30540,
#  'than their': 38777,
#  'their funny': 42567,
#  'funny accents': 15532,
#  'rrb and': 34193,
#  'the action': 39490,
#  'action scenes': 642,
#  'scenes are': 34570,
#  'lrb other than': 24093,
#  'other than their': 30544,
#  'than their funny': 38779,
#  'their funny accents': 42568,
#  'the action scenes': 39494,
#  'the characters': 39808,
#  'characters are': 8202,
#  'are more': 4042,
#  'through than': 43516,
#  'in most': 19413,
#  'right thinking': 33951,
#  'the characters are': 39810,
#  'despite the': 10574,
#  'is still': 20948,
#  'still good': 37263,
#  'good fun': 16259,
#  'the script': 41766,
#  'ham fisted': 16840,
#  'designed to': 10549,
#  'garner the': 15694,
#  'film cooler': 13859,
#  'cooler pg': 9501,
#  'pg 13': 31594,
#  '13 rating': 43,
#  'garner the film': 15695,
#  'the film cooler': 40352,
#  'film cooler pg': 13860,
#  'cooler pg 13': 9502,
#  'pg 13 rating': 31595,
#  'drama that': 11416,
#  'that does': 38942,
#  'does the': 11229,
#  'the nearly': 41204,
#  'nearly impossible': 26743,
#  'it gets': 21230,
#  'gets under': 15896,
#  'under the': 45895,
#  'the skin': 41881,
#  'skin of': 35991,
#  'of man': 28481,
#  'we only': 47356,
#  'only know': 30083,
#  'know as': 22509,
#  'as an': 4252,
#  'an evil': 1755,
#  'evil monstrous': 12800,
#  'monstrous lunatic': 25596,
#  'the nearly impossible': 41205,
#  'gets under the': 15897,
#  'under the skin': 45899,
#  'the skin of': 41882,
#  'skin of man': 35992,
#  'we only know': 47357,
#  'only know as': 30084,
#  'know as an': 22510,
#  'as an evil': 4256,
#  'an evil monstrous': 1756,
#  'evil monstrous lunatic': 12801,
#  'many things': 24678,
#  'stoner midnight': 37319,
#  'midnight flick': 25253,
#  'flick sci': 14397,
#  'sci fi': 34625,
#  'fi deconstruction': 13736,
#  'all it': 1122,
#  'love story': 23923,
#  'story as': 37364,
#  'as its': 4437,
#  'its title': 21907,
#  'stoner midnight flick': 37320,
#  'midnight flick sci': 25254,
#  'flick sci fi': 14398,
#  'sci fi deconstruction': 34628,
#  'as its title': 4442,
#  'very funny': 46549,
#  'comedy about': 8981,
#  'about two': 403,
#  'new york': 26961,
#  'middle agers': 25234,
#  'who stumble': 48131,
#  'stumble into': 37628,
#  'relationship and': 33521,
#  'and then': 3360,
#  'with their': 48864,
#  'fears and': 13505,
#  'and foibles': 2465,
#  'who stumble into': 48132,
#  'it has': 21251,
#  'has an': 17012,
#  'ambition to': 1423,
#  'say something': 34531,
#  'something about': 36567,
#  'about its': 308,
#  'its subjects': 21889,
#  'but not': 7231,
#  'but it has': 7200,
#  'ambition to say': 1424,
#  'to say something': 44613,
#  'say something about': 34532,
#  'something about its': 36569,
#  'about its subjects': 310,
#  'rrb has': 34212,
#  'has made': 17085,
#  'made movie': 24246,
#  'movie that': 26242,
#  'that will': 39419,
#  'will leave': 48328,
#  'you wondering': 49795,
#  'wondering about': 49080,
#  'characters lives': 8224,
#  'lives after': 23559,
#  'after the': 906,
#  'the clever': 39867,
#  'clever credits': 8699,
#  'credits roll': 9791,
#  'made movie that': 24248,
#  'movie that will': 26253,
#  'will leave you': 48330,
#  'wondering about the': 49081,
#  'about the characters': 369,
#  'the characters lives': 39814,
#  'characters lives after': 8225,
#  'lives after the': 23560,
#  'after the clever': 907,
#  'the clever credits': 39868,
#  'clever credits roll': 8700,
#  'an rrb': 1909,
#  'work from': 49127,
#  'of vignettes': 29279,
#  'that are': 38847,
#  'are still': 4078,
#  'looking for': 23769,
#  'common through': 9123,
#  'through line': 43502,
#  'series of vignettes': 35250,
#  'of film that': 28086,
#  'common through line': 9124,
#  'problem with': 32464,
#  'is that': 20974,
#  'on the': 29775,
#  'the wrong': 42466,
#  'is that the': 20978,
#  'of the movie': 29064,
#  'fatal attraction': 13464,
#  'high school': 17790,
#  'school swimming': 34614,
#  'substitutes for': 37736,
#  'for bathtub': 14531,
#  'high school swimming': 17793,
#  'substitutes for bathtub': 37737,
#  'this is': 43123,
#  'is heartfelt': 20726,
#  'it just': 21291,
#  'just is': 22247,
#  'is very': 21030,
#  'an unsettling': 1947,
#  'experience that': 12967,
#  'does its': 11194,
#  'all in': 1116,
#  'in all': 19079,
#  'it pretty': 21383,
#  'pretty good': 32367,
#  'execution of': 12899,
#  'story that': 37402,
#  'lot richer': 23853,
#  'richer than': 33905,
#  'than the': 38763,
#  'the ones': 41295,
#  'ones hollywood': 30034,
#  'hollywood action': 18286,
#  'action screenwriters': 643,
#  'screenwriters usually': 34732,
#  'usually come': 46368,
#  'come up': 8963,
#  'up with': 46214,
#  'with on': 48700,
#  'on their': 29831,
#  'their own': 42617,
#  'all in all': 1117,
#  'lot richer than': 23854,
#  'richer than the': 33907,
#  'than the ones': 38769,
#  'the ones hollywood': 41296,
#  'ones hollywood action': 30035,
#  'hollywood action screenwriters': 18289,
#  'action screenwriters usually': 644,
#  'screenwriters usually come': 34733,
#  'usually come up': 46369,
#  'come up with': 8964,
#  'up with on': 46217,
#  'with on their': 48702,
#  'on their own': 29833,
#  'all of': 1145,
#  'his actors': 17907,
#  'actors as': 683,
#  'as well': 4667,
#  'well as': 47467,
#  'as his': 4405,
#  'his cinematographer': 17939,
#  'christopher doyle': 8493,
#  'understand the': 45936,
#  'the delicate': 40033,
#  'of greene': 28166,
#  'and it': 2664,
#  'it there': 21444,
#  'the screen': 41754,
#  'screen in': 34690,
#  'in their': 19699,
#  'version of': 46511,
#  'the quiet': 41590,
#  'quiet american': 32879,
#  'and all of': 2008,
#  'all of his': 1146,
#  'of his actors': 28220,
#  'actors as well': 684,
#  'as well as': 4668,
#  'on the screen': 29814,
#  'the screen in': 41756,
#  'version of the': 46515,
#  'the quiet american': 41591,
#  'the pianist': 41434,
#  'lacks the': 22605,
#  'of steven': 28902,
#  'steven spielberg': 37236,
#  'of steven spielberg': 28903,
#  'indulgent and': 19929,
#  'self indulgent and': 35111,
#  'compelling story': 9166,
#  'by david': 7349,
#  'and directed': 2317,
#  'there something': 42770,
#  'about mary': 324,
#  'co writer': 8818,
#  'there something about': 42771,
#  'something about mary': 36570,
#  'viewing for': 46717,
#  'for its': 14638,
#  'its courage': 21612,
#  'courage ideas': 9641,
#  'and great': 2530,
#  'its courage ideas': 21613,
#  'in imax': 19329,
#  'in short': 19520,
#  'just as': 22215,
#  'the big': 39687,
#  'on the big': 29779,
#  'the big screen': 39690,
#  'slice of': 36039,
#  'of life': 28431,
#  'life that': 23147,
#  'very different': 46539,
#  'different from': 10732,
#  'from our': 15316,
#  'our own': 30615,
#  'own and': 30944,
#  'and yet': 3558,
#  'yet instantly': 49538,
#  'instantly recognizable': 20110,
#  'of life that': 28435,
#  'very different from': 46540,
#  'different from our': 10733,
#  'from our own': 15317,
#  'our own and': 30616,
#  'own and yet': 30945,
#  'and yet instantly': 3560,
#  'yet instantly recognizable': 49539,
#  'amid the': 1500,
#  'shock and': 35524,
#  'examination of': 12833,
#  'of young': 29371,
#  'young actress': 49799,
#  'trying to': 45523,
#  'to find': 44175,
#  'find her': 14134,
#  'her way': 17719,
#  'film is just': 13905,
#  'examination of young': 12836,
#  'to find her': 44179,
#  'find her way': 14135,
#  'for movie': 14676,
#  'movie to': 26265,
#  'one problem': 29985,
#  'by trying': 7534,
#  'to distract': 44049,
#  'distract us': 11033,
#  'us with': 46317,
#  'with the': 48823,
#  'the solution': 41908,
#  'solution to': 36446,
#  'to another': 43778,
#  'for movie to': 14678,
#  'distract us with': 11034,
#  'us with the': 46320,
#  'with the solution': 48854,
#  'the solution to': 41909,
#  'solution to another': 36447,
#  'it as': 21115,
#  'any dummies': 3741,
#  'dummies guide': 11610,
#  'can enjoy': 7715,
#  'any dummies guide': 3742,
#  'not so': 27393,
#  'so much': 36309,
#  'because of': 5813,
#  'of its': 28333,
#  'through the': 43517,
#  'pleasure of': 31853,
#  'of watching': 29295,
#  'disney scrape': 10997,
#  'scrape the': 34670,
#  'the bottom': 39720,
#  'bottom of': 6779,
#  'its own': 21765,
#  'own cracker': 30961,
#  'cracker barrel': 9672,
#  'not so much': 27396,
#  'because of its': 5814,
#  'pleasure of watching': 31855,
#  'disney scrape the': 10998,
#  'scrape the bottom': 34671,
#  'the bottom of': 39722,
#  'bottom of its': 6780,
#  'of its own': 28351,
#  'its own cracker': 21770,
#  'own cracker barrel': 30962,
#  'writer director': 49404,
#  'director burr': 10832,
#  'burr steers': 7114,
#  'emphasizes the': 12064,
#  'with mixed': 48674,
#  'director burr steers': 10833,
#  'the number': 41261,
#  'number of': 27558,
#  'blowing through': 6598,
#  ...}

# %%
from scipy.sparse import hstack
train_ft = hstack([train_counts, train_features])
print(train_ft.shape)
# Out:
# (156060, 65240)

# %% [markdown]
# **模型训练**

# %%
from sklearn.linear_model import SGDClassifier

clf = SGDClassifier()

# %%
clf.fit(train_ft, y_train)
# Out:
# SGDClassifier()

# %% [markdown]
# **模型预测**

# %%
test_tsv = pd.read_csv('./data/test.tsv', sep='\t')
x_test = test_tsv['Phrase']
test_counts = counter.transform(x_test)
test_features = tfidf.transform(x_test)
test_ft = hstack([test_counts, test_features])
y_test = clf.predict(test_ft)

# %%
test_tsv['Sentiment'] = y_test

# %%
test_tsv[['PhraseId', 'Sentiment']].to_csv('sklearn_result.csv', index=False)

# %% [markdown]
# **测试结果**
#
# BoW: 0.58545
#
# Tfidf: 0.55975
#
# BoW + Tfidf 3-gram: 0.59070
#
# BoW + Tfidf 3-gram: 0.57690 (loss = logloss)
